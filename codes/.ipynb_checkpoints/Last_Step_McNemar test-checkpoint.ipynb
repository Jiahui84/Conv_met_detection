# %% [markdown]
# # Evaluation: McNemar test

# %% [markdown]
# The experiments with 0-shot, 1-shot, 5-shot, and 10-shot were each run three times, so we also performed three comparisons when comparing different shots.

# %%
# Load libraries
import pandas as pd
import os
import re
from statsmodels.stats.contingency_tables import mcnemar
from itertools import combinations
from pathlib import Path

# %% [markdown]
# ## Comparison of same prompt in different shot prompting

# %%
# Define base folder path
base_folder = '../outputs/output_{}/csv/sorted/'

# Define folder paths
folders = [base_folder.format(i) for i in [0, 1, 5, 10]]

# Get the list of files in each folder
def get_files(folder):
    return sorted([f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))])

# Get the common file names
common_files = ['first_order_sorted.csv', 'second_order_sorted.csv', 'third_order_sorted.csv']

# Define significance level
alpha = 0.05

def compare_files(file1, file2):
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)

    # Ensure ground truth columns are the same
    assert all(df1['DELMET'] == df2['DELMET']), "Ground truth labels do not match."

    results = []

    # Perform McNemar's test for each label_i
    for i in range(1, 26):
        label_col = f'label_{i}'

        # Create 2x2 confusion matrix
        b = sum((df1[label_col] == df1['DELMET']) & (df2[label_col] != df2['DELMET']))
        c = sum((df1[label_col] != df1['DELMET']) & (df2[label_col] == df2['DELMET']))

        # Conduct McNemar's test
        table = [[0, b], [c, 0]]  # Only b and c are needed
        result = mcnemar(table, exact=True)

        # Determine if the difference is significant
        significance = 'significant' if result.pvalue < alpha else 'not significant'

        # Save results
        results.append((label_col, result.pvalue, significance))

    return results

# Create log file
log_file = '../analysis/McNemar_test/mcnemar_results.log'

# Iterate through each pair of folders and compare files
with open(log_file, 'w') as f:
    for folder1, folder2 in combinations(folders, 2):
        files1 = get_files(folder1)
        files2 = get_files(folder2)
        
        f.write(f'Comparing {folder1} and {folder2}:\n')

        for common_file in common_files:
            file1_list = [f for f in files1 if common_file in f]
            file2_list = [f for f in files2 if common_file in f]
            
            if file1_list and file2_list:
                file1 = file1_list[0]
                file2 = file2_list[0]

                results = compare_files(os.path.join(folder1, file1), os.path.join(folder2, file2))

                # Write results to the log file
                f.write(f'Results for {common_file}:\n')
                for label, pvalue, significance in results:
                    f.write(f'{label}: p-value = {pvalue}, {significance}\n')
                f.write('\n')
            else:
                f.write(f'Files not found for {common_file}\n\n')

        f.write('---\n')  # Separate results for different folder combinations

# %%
# Parse the log file
def parse_mcnemar_log(log_file):
    with open(log_file, 'r') as file:
        lines = file.readlines()
    
    data = []
    comparison = ''
    prompt = ''
    
    for line in lines:
        line = line.strip()
        print(f"Processing line: {line}")  # Added debug information
        
        if line.startswith('Comparing'):
            parts = line.split(': ')
            if len(parts) > 1:
                comparison = parts[1]
            else:
                comparison = 'Unknown Comparison'
            print(f"Parsed comparison: {comparison}")
        
        elif line.startswith('Results for'):
            parts = line.split(': ')
            if len(parts) > 1:
                prompt = parts[1]
            else:
                prompt = 'Unknown Prompt'
            print(f"Parsed prompt: {prompt}")
        
        elif 'p-value' in line:
            # Modified regex to match p-value in scientific notation
            match = re.match(r'(label_\d+): p-value = ([\d.e-]+), (significant|not significant)', line)
            if match:
                label = match.group(1)
                p_value = float(match.group(2))
                significance = match.group(3)
                data.append((comparison, prompt, label, p_value, significance))
            else:
                print(f"Unrecognized line format: {line}")
    
    df = pd.DataFrame(data, columns=['Comparison', 'Prompt', 'Label', 'P-Value', 'Significance'])
    return df

# Read the log file
log_file_path = '../analysis/McNemar_test/Comparison_across_shots.log'
df = parse_mcnemar_log(log_file_path)

# Check the contents of the DataFrame
print(df.head())

# Count the number of significant results for each shot setting comparison
significance_counts = df[df['Significance'] == 'significant'].groupby('Comparison').size().reset_index(name='Significant Count')

# Display significance results
print(significance_counts)

# Analyze the distribution of significance across different prompt and shot setting combinations
significance_distribution = df.pivot_table(index='Prompt', columns='Comparison', values='Significance', aggfunc=lambda x: (x == 'significant').sum())
print(significance_distribution)

# Trend analysis (e.g., does increasing the shot setting always improve performance?)
trend_analysis = df.groupby('Comparison').apply(lambda x: (x['Significance'] == 'significant').sum() / len(x)).reset_index(name='Significance Ratio')
print(trend_analysis)

# Plotting
import matplotlib.pyplot as plt

# Display a bar chart of significant counts
significance_counts.plot(kind='bar', x='Comparison', y='Significant Count')
plt.title('Significant Count by Comparison')
plt.xlabel('Comparison')
plt.ylabel('Significant Count')
plt.xticks(rotation=45)
plt.show()

# Display the change in significance ratio by comparison
trend_analysis.plot(kind='line', x='Comparison', y='Significance Ratio', marker='o')
plt.title('Significance Ratio by Comparison')
plt.xlabel('Comparison')
plt.ylabel('Significance Ratio')
plt.xticks(rotation=45)
plt.show()
# Out:
# Processing line: Comparing ../outputs/output_0/csv/sorted/ and ../outputs/output_1/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.44038254337953064, no significant
# Processing line: label_2: p-value = 0.12500454132583336, no significant
# Processing line: label_3: p-value = 0.7860578568938608, no significant
# Processing line: label_4: p-value = 0.00415847306478204, significant
# Processing line: label_5: p-value = 0.4655089982676935, no significant
# Processing line: label_6: p-value = 0.21032725479608821, no significant
# Processing line: label_7: p-value = 0.5499954415754412, no significant
# Processing line: label_8: p-value = 0.5543865913391658, no significant
# Processing line: label_9: p-value = 0.06615259746138927, no significant
# Processing line: label_10: p-value = 0.7375543089843226, no significant
# Processing line: label_11: p-value = 0.3455925658608848, no significant
# Processing line: label_12: p-value = 0.9240973917982833, no significant
# Processing line: label_13: p-value = 0.4850003146822084, no significant
# Processing line: label_14: p-value = 0.006052539424559368, significant
# Processing line: label_15: p-value = 0.22727494633160858, no significant
# Processing line: label_16: p-value = 0.7687918101386723, no significant
# Processing line: label_17: p-value = 0.7511907919533753, no significant
# Processing line: label_18: p-value = 0.790702788726708, no significant
# Processing line: label_19: p-value = 0.8699229710286408, no significant
# Processing line: label_20: p-value = 0.1292576635775832, no significant
# Processing line: label_21: p-value = 0.06773846291156918, no significant
# Processing line: label_22: p-value = 2.6032078607741377e-18, significant
# Processing line: label_23: p-value = 0.7481109519787561, no significant
# Processing line: label_24: p-value = 0.6770697943668328, no significant
# Processing line: label_25: p-value = 0.0013902601073185463, significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.9306844655255777, no significant
# Processing line: label_2: p-value = 0.2021731060961757, no significant
# Processing line: label_3: p-value = 0.6255036238897118, no significant
# Processing line: label_4: p-value = 1.0, no significant
# Processing line: label_5: p-value = 0.4712861032196056, no significant
# Processing line: label_6: p-value = 0.183657171901775, no significant
# Processing line: label_7: p-value = 1.4360207833643e-36, significant
# Processing line: label_8: p-value = 0.13033475483295076, no significant
# Processing line: label_9: p-value = 0.3193082974752449, no significant
# Processing line: label_10: p-value = 0.3018724904870079, no significant
# Processing line: label_11: p-value = 0.5310454494607929, no significant
# Processing line: label_12: p-value = 0.8546300421797661, no significant
# Processing line: label_13: p-value = 0.7384057149811339, no significant
# Processing line: label_14: p-value = 0.18374624131166653, no significant
# Processing line: label_15: p-value = 0.028089467947778165, significant
# Processing line: label_16: p-value = 0.5583942911655909, no significant
# Processing line: label_17: p-value = 0.6871492187686523, no significant
# Processing line: label_18: p-value = 1.0, no significant
# Processing line: label_19: p-value = 0.9312017456335957, no significant
# Processing line: label_20: p-value = 0.09018463240010803, no significant
# Processing line: label_21: p-value = 0.543159839477347, no significant
# Processing line: label_22: p-value = 0.7117032769279408, no significant
# Processing line: label_23: p-value = 0.1476620972185266, no significant
# Processing line: label_24: p-value = 3.774053391516933e-143, significant
# Processing line: label_25: p-value = 0.20999518680228452, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.013712033079849195, significant
# Processing line: label_2: p-value = 0.7709189909371149, no significant
# Processing line: label_3: p-value = 1.329028919570328e-18, significant
# Processing line: label_4: p-value = 0.7224376926298612, no significant
# Processing line: label_5: p-value = 0.058224644034741084, no significant
# Processing line: label_6: p-value = 0.18122406088142354, no significant
# Processing line: label_7: p-value = 0.6445422120603314, no significant
# Processing line: label_8: p-value = 0.47688215872526807, no significant
# Processing line: label_9: p-value = 0.0011086208878113386, significant
# Processing line: label_10: p-value = 0.09183767826908254, no significant
# Processing line: label_11: p-value = 0.3346877587369284, no significant
# Processing line: label_12: p-value = 1.0, no significant
# Processing line: label_13: p-value = 0.3281819596032337, no significant
# Processing line: label_14: p-value = 0.3749570506813299, no significant
# Processing line: label_15: p-value = 0.19534905940457836, no significant
# Processing line: label_16: p-value = 0.46348817662276376, no significant
# Processing line: label_17: p-value = 0.42783981112503267, no significant
# Processing line: label_18: p-value = 0.826880316057374, no significant
# Processing line: label_19: p-value = 0.40310390913216976, no significant
# Processing line: label_20: p-value = 0.059798913627112295, no significant
# Processing line: label_21: p-value = 0.5777428358653738, no significant
# Processing line: label_22: p-value = 1.0, no significant
# Processing line: label_23: p-value = 0.014799505045483288, significant
# Processing line: label_24: p-value = 2.586235003305433e-81, significant
# Processing line: label_25: p-value = 0.0002621681296867191, significant
# Processing line:
# Processing line: ---
# Processing line: Comparing ../outputs/output_0/csv/sorted/ and ../outputs/output_5/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.7807391284762693, no significant
# Processing line: label_2: p-value = 0.1046130581112671, no significant
# Processing line: label_3: p-value = 0.20817442238117598, no significant
# Processing line: label_4: p-value = 0.22323036245554492, no significant
# Processing line: label_5: p-value = 0.0011086208878113386, significant
# Processing line: label_6: p-value = 0.1842858728803648, no significant
# Processing line: label_7: p-value = 0.009683555095331005, significant
# Processing line: label_8: p-value = 0.24670624718941742, no significant
# Processing line: label_9: p-value = 0.28528442186565817, no significant
# Processing line: label_10: p-value = 0.06508646998863736, no significant
# Processing line: label_11: p-value = 0.07784940675335604, no significant
# Processing line: label_12: p-value = 0.010817905625818625, significant
# Processing line: label_13: p-value = 0.9196068309220428, no significant
# Processing line: label_14: p-value = 0.7999564140878658, no significant
# Processing line: label_15: p-value = 0.26489299040582087, no significant
# Processing line: label_16: p-value = 0.005682824660016618, significant
# Processing line: label_17: p-value = 0.41907374251663526, no significant
# Processing line: label_18: p-value = 0.2916544513344343, no significant
# Processing line: label_19: p-value = 0.8569843282497004, no significant
# Processing line: label_20: p-value = 0.20147303457231988, no significant
# Processing line: label_21: p-value = 0.6927623491186462, no significant
# Processing line: label_22: p-value = 1.1046769616716427e-14, significant
# Processing line: label_23: p-value = 0.8026933550697285, no significant
# Processing line: label_24: p-value = 0.27524996897157333, no significant
# Processing line: label_25: p-value = 0.7570261671839611, no significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.038179441579785374, significant
# Processing line: label_2: p-value = 0.007178115485500818, significant
# Processing line: label_3: p-value = 0.03521102017980901, significant
# Processing line: label_4: p-value = 0.05789389156677773, no significant
# Processing line: label_5: p-value = 0.12385305946180147, no significant
# Processing line: label_6: p-value = 0.2830852395827475, no significant
# Processing line: label_7: p-value = 0.013183368381607285, significant
# Processing line: label_8: p-value = 0.787746582402333, no significant
# Processing line: label_9: p-value = 0.9999999999999989, no significant
# Processing line: label_10: p-value = 0.12847543208575962, no significant
# Processing line: label_11: p-value = 0.007234542621729916, significant
# Processing line: label_12: p-value = 0.12929258395357346, no significant
# Processing line: label_13: p-value = 0.0026846980412799162, significant
# Processing line: label_14: p-value = 0.4655089982676935, no significant
# Processing line: label_15: p-value = 0.5792902501877023, no significant
# Processing line: label_16: p-value = 0.6207676687971155, no significant
# Processing line: label_17: p-value = 0.8581193732635908, no significant
# Processing line: label_18: p-value = 0.024793536339643683, significant
# Processing line: label_19: p-value = 1.0, no significant
# Processing line: label_20: p-value = 0.22690555254948563, no significant
# Processing line: label_21: p-value = 0.6635853603383618, no significant
# Processing line: label_22: p-value = 0.009966324337995335, significant
# Processing line: label_23: p-value = 0.9999999999999996, no significant
# Processing line: label_24: p-value = 2.5423051446528716e-141, significant
# Processing line: label_25: p-value = 1.0, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.05232353322391847, no significant
# Processing line: label_2: p-value = 0.2191311474977842, no significant
# Processing line: label_3: p-value = 4.802163516364586e-14, significant
# Processing line: label_4: p-value = 0.022375141333215814, significant
# Processing line: label_5: p-value = 0.07091955904416077, no significant
# Processing line: label_6: p-value = 0.1985836053080508, no significant
# Processing line: label_7: p-value = 2.9391095138567976e-35, significant
# Processing line: label_8: p-value = 0.0329697564108826, significant
# Processing line: label_9: p-value = 0.2791985549760791, no significant
# Processing line: label_10: p-value = 0.23230046428473827, no significant
# Processing line: label_11: p-value = 0.06520677354687988, no significant
# Processing line: label_12: p-value = 0.3775839232980986, no significant
# Processing line: label_13: p-value = 0.001727170354402501, significant
# Processing line: label_14: p-value = 0.2191311474977842, no significant
# Processing line: label_15: p-value = 0.4335671268286529, no significant
# Processing line: label_16: p-value = 0.6454967635578226, no significant
# Processing line: label_17: p-value = 0.008032780505172027, significant
# Processing line: label_18: p-value = 0.1973384159435853, no significant
# Processing line: label_19: p-value = 9.25884384181139e-46, significant
# Processing line: label_20: p-value = 0.18975855790673776, no significant
# Processing line: label_21: p-value = 0.00032713047727164665, significant
# Processing line: label_22: p-value = 0.25460512309379424, no significant
# Processing line: label_23: p-value = 0.4237736910837465, no significant
# Processing line: label_24: p-value = 8.528106018630423e-79, significant
# Processing line: label_25: p-value = 0.45216214324561105, no significant
# Processing line:
# Processing line: ---
# Processing line: Comparing ../outputs/output_0/csv/sorted/ and ../outputs/output_10/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.3309358289422146, no significant
# Processing line: label_2: p-value = 0.9234010375945971, no significant
# Processing line: label_3: p-value = 0.7398815747182799, no significant
# Processing line: label_4: p-value = 0.4307246551015168, no significant
# Processing line: label_5: p-value = 0.5007663934164359, no significant
# Processing line: label_6: p-value = 0.5507089135982715, no significant
# Processing line: label_7: p-value = 0.1656611716989778, no significant
# Processing line: label_8: p-value = 0.8748178672015423, no significant
# Processing line: label_9: p-value = 1.0, no significant
# Processing line: label_10: p-value = 0.7734911416953504, no significant
# Processing line: label_11: p-value = 0.4114232202639379, no significant
# Processing line: label_12: p-value = 0.9234010375945971, no significant
# Processing line: label_13: p-value = 0.000913112874001578, significant
# Processing line: label_14: p-value = 0.8114566072042915, no significant
# Processing line: label_15: p-value = 0.30524277813335265, no significant
# Processing line: label_16: p-value = 0.23828700628615238, no significant
# Processing line: label_17: p-value = 0.6659501639012324, no significant
# Processing line: label_18: p-value = 0.34911516637678125, no significant
# Processing line: label_19: p-value = 0.7925825227940955, no significant
# Processing line: label_20: p-value = 0.11469594326965232, no significant
# Processing line: label_21: p-value = 0.1427180761829656, no significant
# Processing line: label_22: p-value = 1.0381775717659965e-17, significant
# Processing line: label_23: p-value = 0.938894973592395, no significant
# Processing line: label_24: p-value = 0.7185088365549661, no significant
# Processing line: label_25: p-value = 0.14123755901020996, no significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.21805368187049962, no significant
# Processing line: label_2: p-value = 0.8508699225134504, no significant
# Processing line: label_3: p-value = 0.5892869358592503, no significant
# Processing line: label_4: p-value = 0.05353757584043605, no significant
# Processing line: label_5: p-value = 0.9219488276264309, no significant
# Processing line: label_6: p-value = 0.6172994135892521, no significant
# Processing line: label_7: p-value = 0.18793326274141767, no significant
# Processing line: label_8: p-value = 0.08607110318597093, no significant
# Processing line: label_9: p-value = 0.5856255178555007, no significant
# Processing line: label_10: p-value = 0.6642959893958239, no significant
# Processing line: label_11: p-value = 0.285216687181283, no significant
# Processing line: label_12: p-value = 0.11721294197631511, no significant
# Processing line: label_13: p-value = 0.1649069826564431, no significant
# Processing line: label_14: p-value = 0.14166174981277396, no significant
# Processing line: label_15: p-value = 0.5297694043652669, no significant
# Processing line: label_16: p-value = 0.08016994071057783, no significant
# Processing line: label_17: p-value = 0.15344375016434325, no significant
# Processing line: label_18: p-value = 0.20147303457231988, no significant
# Processing line: label_19: p-value = 0.6083841068999604, no significant
# Processing line: label_20: p-value = 0.1917961748699362, no significant
# Processing line: label_21: p-value = 0.6963409692892952, no significant
# Processing line: label_22: p-value = 0.4261600154669939, no significant
# Processing line: label_23: p-value = 0.4850003146822084, no significant
# Processing line: label_24: p-value = 4.551973747651013e-138, significant
# Processing line: label_25: p-value = 0.9999999999999991, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.02707352909398981, significant
# Processing line: label_2: p-value = 0.9999999999999998, no significant
# Processing line: label_3: p-value = 7.948420725522052e-22, significant
# Processing line: label_4: p-value = 0.21032725479608821, no significant
# Processing line: label_5: p-value = 0.6991749840078747, no significant
# Processing line: label_6: p-value = 0.49675439302894586, no significant
# Processing line: label_7: p-value = 0.9442053244754732, no significant
# Processing line: label_8: p-value = 1.0, no significant
# Processing line: label_9: p-value = 0.8634152303019916, no significant
# Processing line: label_10: p-value = 0.06210676585298505, no significant
# Processing line: label_11: p-value = 0.4672071020769664, no significant
# Processing line: label_12: p-value = 0.21497653774329664, no significant
# Processing line: label_13: p-value = 0.26305395754293576, no significant
# Processing line: label_14: p-value = 0.9296139078299844, no significant
# Processing line: label_15: p-value = 1.0, no significant
# Processing line: label_16: p-value = 0.45648223496512547, no significant
# Processing line: label_17: p-value = 0.503639489729781, no significant
# Processing line: label_18: p-value = 0.14463646515752152, no significant
# Processing line: label_19: p-value = 0.7971023348689007, no significant
# Processing line: label_20: p-value = 0.3271229672167791, no significant
# Processing line: label_21: p-value = 0.5522070718494918, no significant
# Processing line: label_22: p-value = 0.2712530240738354, no significant
# Processing line: label_23: p-value = 0.6307898865914237, no significant
# Processing line: label_24: p-value = 1.1297643357296371e-82, significant
# Processing line: label_25: p-value = 0.04744112748635077, significant
# Processing line:
# Processing line: ---
# Processing line: Comparing ../outputs/output_1/csv/sorted/ and ../outputs/output_5/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.670534100245501, no significant
# Processing line: label_2: p-value = 0.0008214525388957499, significant
# Processing line: label_3: p-value = 0.15865371419232277, no significant
# Processing line: label_4: p-value = 2.7552798008748024e-05, significant
# Processing line: label_5: p-value = 0.0006293470747506883, significant
# Processing line: label_6: p-value = 0.0075848117754316186, significant
# Processing line: label_7: p-value = 0.019677394492866023, significant
# Processing line: label_8: p-value = 0.0979297103970037, no significant
# Processing line: label_9: p-value = 0.007846593122439722, significant
# Processing line: label_10: p-value = 0.025543364029782935, significant
# Processing line: label_11: p-value = 0.005325740283781563, significant
# Processing line: label_12: p-value = 0.03992817966861652, significant
# Processing line: label_13: p-value = 0.5836922618268336, no significant
# Processing line: label_14: p-value = 0.0007995844433963236, significant
# Processing line: label_15: p-value = 0.01843057167038033, significant
# Processing line: label_16: p-value = 0.0010844284704958557, significant
# Processing line: label_17: p-value = 0.27571405722982145, no significant
# Processing line: label_18: p-value = 0.5782913753157676, no significant
# Processing line: label_19: p-value = 0.6727565036145107, no significant
# Processing line: label_20: p-value = 0.00548246878576062, significant
# Processing line: label_21: p-value = 0.014359642888005224, significant
# Processing line: label_22: p-value = 0.0566032699703337, no significant
# Processing line: label_23: p-value = 1.0, no significant
# Processing line: label_24: p-value = 0.5598211377107964, no significant
# Processing line: label_25: p-value = 0.0002592477182359919, significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.06002721569726564, no significant
# Processing line: label_2: p-value = 4.410029455394906e-05, significant
# Processing line: label_3: p-value = 0.006479665826347685, significant
# Processing line: label_4: p-value = 0.10552229968115755, no significant
# Processing line: label_5: p-value = 0.06137832710948887, no significant
# Processing line: label_6: p-value = 0.023125726989789167, significant
# Processing line: label_7: p-value = 3.77880925236624e-29, significant
# Processing line: label_8: p-value = 0.08380154521018608, no significant
# Processing line: label_9: p-value = 0.2906878547807372, no significant
# Processing line: label_10: p-value = 0.018693425409254078, significant
# Processing line: label_11: p-value = 0.0006916620893659545, significant
# Processing line: label_12: p-value = 0.10703141160601269, no significant
# Processing line: label_13: p-value = 0.10930711609979489, no significant
# Processing line: label_14: p-value = 0.6208422313416986, no significant
# Processing line: label_15: p-value = 0.007846593122439722, significant
# Processing line: label_16: p-value = 0.23690187778029256, no significant
# Processing line: label_17: p-value = 0.4975641415966086, no significant
# Processing line: label_18: p-value = 0.07254166975912615, no significant
# Processing line: label_19: p-value = 0.9317076151509965, no significant
# Processing line: label_20: p-value = 0.5870535639169907, no significant
# Processing line: label_21: p-value = 0.24812572575379216, no significant
# Processing line: label_22: p-value = 0.004786266356000363, significant
# Processing line: label_23: p-value = 0.10905618827674632, no significant
# Processing line: label_24: p-value = 0.23520336797252492, no significant
# Processing line: label_25: p-value = 0.20717984725922278, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.5570709871103283, no significant
# Processing line: label_2: p-value = 0.12957613928638614, no significant
# Processing line: label_3: p-value = 0.06701041475229508, no significant
# Processing line: label_4: p-value = 0.09220360536584891, no significant
# Processing line: label_5: p-value = 0.0002967526212958216, significant
# Processing line: label_6: p-value = 0.008986616457699331, significant
# Processing line: label_7: p-value = 2.669515780563858e-38, significant
# Processing line: label_8: p-value = 0.005566130513722025, significant
# Processing line: label_9: p-value = 4.270200183798431e-05, significant
# Processing line: label_10: p-value = 0.004195534185394861, significant
# Processing line: label_11: p-value = 0.0017094927839213705, significant
# Processing line: label_12: p-value = 0.3909274566995059, no significant
# Processing line: label_13: p-value = 9.033649284138163e-06, significant
# Processing line: label_14: p-value = 0.8481947835965663, no significant
# Processing line: label_15: p-value = 0.8013390218104018, no significant
# Processing line: label_16: p-value = 0.183657171901775, no significant
# Processing line: label_17: p-value = 0.0006186947801814255, significant
# Processing line: label_18: p-value = 0.0965693533917796, no significant
# Processing line: label_19: p-value = 3.2572780014408973e-42, significant
# Processing line: label_20: p-value = 0.0011229051962340457, significant
# Processing line: label_21: p-value = 0.0025505192526799284, significant
# Processing line: label_22: p-value = 0.26305395754293576, no significant
# Processing line: label_23: p-value = 0.0003032364569661188, significant
# Processing line: label_24: p-value = 0.17329061816573244, no significant
# Processing line: label_25: p-value = 0.007284418097174128, significant
# Processing line:
# Processing line: ---
# Processing line: Comparing ../outputs/output_1/csv/sorted/ and ../outputs/output_10/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.9336249535488024, no significant
# Processing line: label_2: p-value = 0.0985236274022573, no significant
# Processing line: label_3: p-value = 0.543159839477347, no significant
# Processing line: label_4: p-value = 0.0005333992648071451, significant
# Processing line: label_5: p-value = 0.21735618793934283, no significant
# Processing line: label_6: p-value = 0.05682268892317546, no significant
# Processing line: label_7: p-value = 0.42783981112503267, no significant
# Processing line: label_8: p-value = 0.7301611158072397, no significant
# Processing line: label_9: p-value = 0.17140890326024522, no significant
# Processing line: label_10: p-value = 0.9999999999999991, no significant
# Processing line: label_11: p-value = 0.05682268892317546, no significant
# Processing line: label_12: p-value = 1.0, no significant
# Processing line: label_13: p-value = 0.08405280186610643, no significant
# Processing line: label_14: p-value = 0.012660684520477252, significant
# Processing line: label_15: p-value = 0.028195308926877438, significant
# Processing line: label_16: p-value = 0.13468540318097671, no significant
# Processing line: label_17: p-value = 0.9999999999999991, no significant
# Processing line: label_18: p-value = 0.6752771314199637, no significant
# Processing line: label_19: p-value = 1.0, no significant
# Processing line: label_20: p-value = 0.003722449304070797, significant
# Processing line: label_21: p-value = 0.6963409692892952, no significant
# Processing line: label_22: p-value = 0.43353726974233237, no significant
# Processing line: label_23: p-value = 0.8855779994131153, no significant
# Processing line: label_24: p-value = 0.40310390913216976, no significant
# Processing line: label_25: p-value = 0.09842638832808594, no significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.37868766269311877, no significant
# Processing line: label_2: p-value = 0.13535040983481553, no significant
# Processing line: label_3: p-value = 1.0, no significant
# Processing line: label_4: p-value = 0.0934509341766344, no significant
# Processing line: label_5: p-value = 0.45216214324561105, no significant
# Processing line: label_6: p-value = 0.48472021812853044, no significant
# Processing line: label_7: p-value = 3.529792039826833e-33, significant
# Processing line: label_8: p-value = 1.0, no significant
# Processing line: label_9: p-value = 0.7449138782509725, no significant
# Processing line: label_10: p-value = 0.8849851393064467, no significant
# Processing line: label_11: p-value = 0.0768759712533238, no significant
# Processing line: label_12: p-value = 0.08481264433974647, no significant
# Processing line: label_13: p-value = 0.16916994509442762, no significant
# Processing line: label_14: p-value = 1.0, no significant
# Processing line: label_15: p-value = 0.23493150329059775, no significant
# Processing line: label_16: p-value = 0.01843057167038033, significant
# Processing line: label_17: p-value = 0.09668353137621186, no significant
# Processing line: label_18: p-value = 0.2814765790638703, no significant
# Processing line: label_19: p-value = 0.5408115779969368, no significant
# Processing line: label_20: p-value = 0.7014821003407139, no significant
# Processing line: label_21: p-value = 0.8889523448298265, no significant
# Processing line: label_22: p-value = 0.23126568219748722, no significant
# Processing line: label_23: p-value = 0.02501609692725934, significant
# Processing line: label_24: p-value = 0.24812572575379216, no significant
# Processing line: label_25: p-value = 0.29122267055843754, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.8013390218104018, no significant
# Processing line: label_2: p-value = 0.8592278156599693, no significant
# Processing line: label_3: p-value = 0.05490187249732823, no significant
# Processing line: label_4: p-value = 0.5905820614901198, no significant
# Processing line: label_5: p-value = 0.17458216426608175, no significant
# Processing line: label_6: p-value = 0.044885393128895716, significant
# Processing line: label_7: p-value = 0.7624694402612469, no significant
# Processing line: label_8: p-value = 0.56482843586319, no significant
# Processing line: label_9: p-value = 0.005184875677476075, significant
# Processing line: label_10: p-value = 0.6098003976284794, no significant
# Processing line: label_11: p-value = 0.0526677812986243, no significant
# Processing line: label_12: p-value = 0.28193653412987324, no significant
# Processing line: label_13: p-value = 0.950373987389194, no significant
# Processing line: label_14: p-value = 0.44366950120234916, no significant
# Processing line: label_15: p-value = 0.21032725479608821, no significant
# Processing line: label_16: p-value = 0.11545448829225959, no significant
# Processing line: label_17: p-value = 0.9395993719521454, no significant
# Processing line: label_18: p-value = 0.13933409492709242, no significant
# Processing line: label_19: p-value = 0.6343339062839168, no significant
# Processing line: label_20: p-value = 0.380250914548775, no significant
# Processing line: label_21: p-value = 1.0, no significant
# Processing line: label_22: p-value = 0.3346877587369284, no significant
# Processing line: label_23: p-value = 0.02702396051785447, significant
# Processing line: label_24: p-value = 0.8102758772916921, no significant
# Processing line: label_25: p-value = 0.09870072731432863, no significant
# Processing line:
# Processing line: ---
# Processing line: Comparing ../outputs/output_5/csv/sorted/ and ../outputs/output_10/csv/sorted/:
# Parsed comparison: Unknown Comparison
# Processing line: Results for first_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.5330527502675579, no significant
# Processing line: label_2: p-value = 0.137098805756034, no significant
# Processing line: label_3: p-value = 0.5677754876753281, no significant
# Processing line: label_4: p-value = 0.873248139297003, no significant
# Processing line: label_5: p-value = 0.027944840955287726, significant
# Processing line: label_6: p-value = 0.542610158045875, no significant
# Processing line: label_7: p-value = 0.24424992712067164, no significant
# Processing line: label_8: p-value = 0.2210112486397079, no significant
# Processing line: label_9: p-value = 0.3223076486087749, no significant
# Processing line: label_10: p-value = 0.07732325962365362, no significant
# Processing line: label_11: p-value = 0.32913712616613827, no significant
# Processing line: label_12: p-value = 0.03559998587055807, significant
# Processing line: label_13: p-value = 0.0031196232899818725, significant
# Processing line: label_14: p-value = 0.5514132796665477, no significant
# Processing line: label_15: p-value = 1.0, no significant
# Processing line: label_16: p-value = 0.15633984208003932, no significant
# Processing line: label_17: p-value = 0.17064521313035158, no significant
# Processing line: label_18: p-value = 0.9322024875049745, no significant
# Processing line: label_19: p-value = 0.5974849993058731, no significant
# Processing line: label_20: p-value = 0.7415919424461611, no significant
# Processing line: label_21: p-value = 0.04891515703541783, significant
# Processing line: label_22: p-value = 0.18884671980890208, no significant
# Processing line: label_23: p-value = 0.936624069648501, no significant
# Processing line: label_24: p-value = 0.12652294497263625, no significant
# Processing line: label_25: p-value = 0.05343240458128752, no significant
# Processing line:
# Processing line: Results for second_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.2906878547807372, no significant
# Processing line: label_2: p-value = 0.01723638286712919, significant
# Processing line: label_3: p-value = 0.007182068473081055, significant
# Processing line: label_4: p-value = 0.9340795771546325, no significant
# Processing line: label_5: p-value = 0.29807066339153904, no significant
# Processing line: label_6: p-value = 0.1098495025660595, no significant
# Processing line: label_7: p-value = 0.19818134136296922, no significant
# Processing line: label_8: p-value = 0.04498016418904381, significant
# Processing line: label_9: p-value = 0.5264163099662327, no significant
# Processing line: label_10: p-value = 0.10363903843785674, no significant
# Processing line: label_11: p-value = 0.10036570149746159, no significant
# Processing line: label_12: p-value = 0.9247750936572272, no significant
# Processing line: label_13: p-value = 0.0003032364569661188, significant
# Processing line: label_14: p-value = 0.5514132796665477, no significant
# Processing line: label_15: p-value = 0.19534905940457836, no significant
# Processing line: label_16: p-value = 0.19915839818564499, no significant
# Processing line: label_17: p-value = 0.24160419524510135, no significant
# Processing line: label_18: p-value = 0.45969138732555365, no significant
# Processing line: label_19: p-value = 0.5946154859354928, no significant
# Processing line: label_20: p-value = 0.9322024875049745, no significant
# Processing line: label_21: p-value = 0.37233205154529325, no significant
# Processing line: label_22: p-value = 0.09012286584573231, no significant
# Processing line: label_23: p-value = 0.49013856710390075, no significant
# Processing line: label_24: p-value = 1.0, no significant
# Processing line: label_25: p-value = 1.0, no significant
# Processing line:
# Processing line: Results for third_order_sorted.csv:
# Parsed prompt: Unknown Prompt
# Processing line: label_1: p-value = 0.7843281773322767, no significant
# Processing line: label_2: p-value = 0.24812572575379216, no significant
# Processing line: label_3: p-value = 0.0006813642297109454, significant
# Processing line: label_4: p-value = 0.32437346590855476, no significant
# Processing line: label_5: p-value = 0.037718957484689945, significant
# Processing line: label_6: p-value = 0.5206333734262366, no significant
# Processing line: label_7: p-value = 3.146647762495203e-36, significant
# Processing line: label_8: p-value = 0.04306699847787232, significant
# Processing line: label_9: p-value = 0.48756699557998684, no significant
# Processing line: label_10: p-value = 0.006086946806157235, significant
# Processing line: label_11: p-value = 0.22810347806601336, no significant
# Processing line: label_12: p-value = 0.7925825227940955, no significant
# Processing line: label_13: p-value = 0.0002648819674846673, significant
# Processing line: label_14: p-value = 0.3153033008322579, no significant
# Processing line: label_15: p-value = 0.4189205249064943, no significant
# Processing line: label_16: p-value = 0.8013390218104018, no significant
# Processing line: label_17: p-value = 0.0019352292476659421, significant
# Processing line: label_18: p-value = 1.0, no significant
# Processing line: label_19: p-value = 7.490198467465096e-41, significant
# Processing line: label_20: p-value = 0.0329697564108826, significant
# Processing line: label_21: p-value = 0.007794310586633005, significant
# Processing line: label_22: p-value = 1.0, no significant
# Processing line: label_23: p-value = 0.14123755901020996, no significant
# Processing line: label_24: p-value = 0.2979336445419193, no significant
# Processing line: label_25: p-value = 0.2764630123158033, no significant
# Processing line:
# Processing line: ---
#            Comparison          Prompt    Label   P-Value     Significant
# 0  Unknown Comparison  Unknown Prompt  label_1  0.440383  no significant
# 1  Unknown Comparison  Unknown Prompt  label_2  0.125005  no significant
# 2  Unknown Comparison  Unknown Prompt  label_3  0.786058  no significant
# 3  Unknown Comparison  Unknown Prompt  label_4  0.004158     significant
# 4  Unknown Comparison  Unknown Prompt  label_5  0.465509  no significant
#            Comparison  Significant Count
# 0  Unknown Comparison                108
# Comparison      Unknown Comparison
# Prompt
# Unknown Prompt                 108
#            Comparison  Significance Ratio
# 0  Unknown Comparison                0.24

# %% [markdown]
# ## Comparison of different prompts in same shot prompting

# %%
# This function compares the performance of two classifiers (label1 and label2) 
# using McNemar's test to determine if there is a significant difference between them.
def make_contingency_table(data, label1, label2, ground_truth, alpha=.05):
    # Extract predictions of the two classifiers and the ground truth
    results_1 = data[label1]
    results_2 = data[label2]
    ground_truth = data[ground_truth]
    
    # Ensure that all inputs have the same length
    assert len(results_1) == len(results_2) == len(ground_truth), "Error: incompatible sizes."
    
    # Initialize a contingency table for counting occurrences of different outcomes
    Results = {(1, 1): 0, (0, 1): 0, (1, 0): 0, (0, 0): 0}
    performance_1 = sum(results_1 == ground_truth)  # Correct predictions by classifier 1
    performance_2 = sum(results_2 == ground_truth)  # Correct predictions by classifier 2
    
    # Populate the contingency table based on comparison of classifier predictions and ground truth
    for i in range(len(results_1)):
        score_1 = int(results_1[i] == ground_truth[i])
        score_2 = int(results_2[i] == ground_truth[i])
        Results[(score_1, score_2)] += 1
    
    # Create a 2x2 matrix from the contingency results
    table = [[Results[(1, 1)], Results[(1, 0)]],
             [Results[(0, 1)], Results[(0, 0)]]]
    
    # Perform McNemar's test to evaluate the significance of the difference between the two classifiers
    m = mcnemar(table, exact=False)
    
    # Determine if the difference is statistically significant based on the p-value
    significant = "Yes" if m.pvalue <= alpha else "No"
    return (f"{label1} vs {label2}", m.statistic, m.pvalue, significant)

# This function processes each folder containing the results of different shot settings.
# It reads CSV files, compares classifier performance using McNemar's test, 
# and saves the results into a new CSV file.
def process_folder(folder_path):
    # Iterate through folders corresponding to different shot settings
    for subdir in ['output_0', 'output_1', 'output_5', 'output_10']:
        full_path = Path(folder_path) / subdir / 'csv' / 'sorted'
        save_path = Path(folder_path) / 'processed_results' / subdir
        save_path.mkdir(parents=True, exist_ok=True)
        
        # Process each CSV file in the folder
        for csv_file in full_path.glob('*.csv'):
            data = pd.read_csv(csv_file)
            results = []
            
            # Assuming 'DELMET' is the ground truth column and label columns are label_1 to label_25
            classifier_labels = [f'label_{i}' for i in range(1, 26)]
            
            # Compare each pair of classifiers using McNemar's test
            for (label1, label2) in combinations(classifier_labels, 2):
                result = make_contingency_table(data, label1, label2, 'DELMET')
                results.append(result)
            
            # Save the comparison results to a new CSV file
            results_df = pd.DataFrame(results, columns=['Label Pair', 'McNemar Statistic', 'P-Value', 'Significant'])
            result_file_name = csv_file.stem + '_results.csv'
            results_df.to_csv(save_path / result_file_name, index=False)
